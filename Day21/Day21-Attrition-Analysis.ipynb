# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
data = pd.read_csv("Day-21/dataset/general_data.csv")

# %%
data = data.drop('EmployeeID',axis=1)

# %%
data = data.drop('Over18',axis=1)

# %%
data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
data = data.ffill()

# %%
data.isna().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
data['Attrition'] = le.fit_transform(data['Attrition'])
data['BusinessTravel'] = le.fit_transform(data['BusinessTravel'])
data['Department'] = le.fit_transform(data['Department'])
data['EducationField'] = le.fit_transform(data['EducationField'])
data['Gender'] = le.fit_transform(data['Gender'])
data['JobRole'] = le.fit_transform(data['JobRole'])
data['MaritalStatus'] = le.fit_transform(data['MaritalStatus'])

# %%
data
# Out:
#       Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      51          0               2           2                 6          2
# 1      31          1               1           1                10          1
# 2      32          0               1           1                17          4
# 3      38          0               0           1                 2          5
# 4      32          0               2           1                10          1
# ...   ...        ...             ...         ...               ...        ...
# 4405   42          0               2           1                 5          4
# 4406   29          0               2           1                 2          4
# 4407   25          0               2           1                25          2
# 4408   42          0               2           2                18          2
# 4409   40          0               2           1                28          3
#
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'Gender', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
#Split the DV and IDV

X= data[['Age','BusinessTravel', 'Department', 'DistanceFromHome',
       'Education', 'EducationField', 'EmployeeCount', 'Gender', 'JobLevel',
       'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
       'PercentSalaryHike', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager']]
Y = data['Attrition']

# %%
import statsmodels.api as sm
constann = sm.add_constant(X)

# %%
constann
# Out:
#       Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      51               2           2                 6          2
# 1      31               1           1                10          1
# 2      32               1           1                17          4
# 3      38               0           1                 2          5
# 4      32               2           1                10          1
# ...   ...             ...         ...               ...        ...
# 4405   42               2           1                 5          4
# 4406   29               2           1                 2          4
# 4407   25               2           1                25          2
# 4408   42               2           2                18          2
# 4409   40               2           1                28          3
#
#       EducationField  EmployeeCount  Gender  JobLevel  JobRole  ...  \
# 0                  1              1       0         1        0  ...
# ...

# %%
Logistic = sm.Logit(Y,constann)
result = Logistic.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.393154
#          Iterations 7

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 4410
# Model:                          Logit   Df Residuals:                     4390
# Method:                           MLE   Df Model:                           19
# Date:                Fri, 28 Aug 2020   Pseudo R-squ.:                  0.1099
# Time:                        23:30:17   Log-Likelihood:                -1733.8
# converged:                       True   LL-Null:                       -1947.9
# Covariance Type:            nonrobust   LLR p-value:                 6.070e-79
# ...
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Age                        -0.0313      0.007     -4.590      0.000      -0.045      -0.018
# ...

# %% [raw]
# Inference
# =========
#
# Age,Department,EducationField,JobRole,MaritalStatus,MonthlyIncome,NumCompaniesWorked,TotalWorkingYears,TrainingTimesLastYear,YearsSinceLastPromotion,YearsWithCurrManager are the significant variables.
#
# Out of these the most significant variables are
# Age
# Department
# MaritalStatus
# NumCompaniesWorked
# TotalWorkingYears
# TrainingTimesLastYear
# YearsSinceLastPromotion
# YearsWithCurrManager
